# %%
#100 random positive data 
#importing useful python libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv("lightcurve_features_26.csv") #loading feature file
df_shuffled = df.sample(frac=1, random_state=42).reset_index(drop=True) #shuffling the list

# %%
subset_100 = df_shuffled.iloc[:100] #taking 100 randomly for work
subset_39 = df_shuffled.iloc[100:139] #keeping rest 39 in a hidden box

# %%
subset_39.to_csv("Positive_hidden_subset_39.csv", index=False) #save

# %%
subset_100.to_csv("positive_100_elements.csv", index=False) #save

# %%
df_pos=pd.read_csv('positive_100_elements.csv') #loading working file

# %%
df_pos
# Out:
#         object       mean  weighted_mean  standard_deviation     median  \
# 0          Sex  16.484749      15.824940            1.277268  15.927287
# 1       EV UMa  17.458514      16.791143            1.226028  16.916203
# 2   J0325-0814  17.332830      16.824973            0.719419  17.397949
# 3       BZ UMa  16.081775      16.025117            0.378524  16.088368
# 4       ST LMi  16.360346      16.162226            0.755607  16.461016
# ..         ...        ...            ...                 ...        ...
# 95    V418 Gem  16.905293      16.891739            0.130254  16.905872
# 96    V677 And  19.227544      18.342081            0.989385  19.060970
# 97   V2306 Cyg  15.869141      15.860906            0.180194  15.848884
# 98      IL Leo  18.458933      17.494483            0.926653  18.622186
# 99         Oph  15.821274      15.817911            0.129693  15.831488
#
#     amplitude  beyond_1_std     cusum  inter_percentile_range_10   kurtosis  \
# ...

# %%
# Check shape and columns
print(df_pos.shape)
print(df_pos.columns)
# Out:
# (100, 27)
# Index(['object', 'mean', 'weighted_mean', 'standard_deviation', 'median',
#        'amplitude', 'beyond_1_std', 'cusum', 'inter_percentile_range_10',
#        'kurtosis', 'linear_trend', 'linear_trend_sigma', 'linear_trend_noise',
#        'linear_fit_slope', 'linear_fit_slope_sigma', 'linear_fit_reduced_chi2',
#        'magnitude_percentage_ratio_40_5', 'magnitude_percentage_ratio_20_10',
#        'maximum_slope', 'median_absolute_deviation',
#        'median_buffer_range_percentage_10', 'percent_amplitude',
#        'mean_variance', 'anderson_darling_normal', 'chi2', 'skew',
#        'stetson_K'],
#       dtype='object')

# %%
features_pos = df_pos.drop(columns=['object'])
corr_pos = features_pos.corr()

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(corr_pos, cmap='coolwarm', center=0)
plt.title('Feature–Feature Correlation (100 positive Objects)')
plt.tight_layout()
plt.show()
