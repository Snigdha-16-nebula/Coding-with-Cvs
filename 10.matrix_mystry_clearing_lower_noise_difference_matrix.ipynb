# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import glob
# Load both files
df_parquet = pd.read_csv("lightcurve_features_26_negative.parquet")
df_csv = pd.read_csv("positive_100_elements.csv")

# %%
combined = pd.concat([df_parquet, df_csv], ignore_index=True)
# Shuffle all rows
combined = combined.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
combined.to_parquet("baseline set with all neg and 100 pos.parquet", index=False)

print("Combined and shuffled dataset saved as 'baseline set with all neg and 100 pos.parquet'")
print("Total rows:", len(combined))
# Out:
# Combined and shuffled dataset saved as 'baseline set with all neg and 100 pos.parquet'
# Total rows: 1571

# %%
df_combined_baseline = pd.read_parquet("baseline set with all neg and 100 pos.parquet")
features_combined_baseline = df_combined_baseline .drop(columns=['object'])
corr_combined_baseline = features_combined_baseline.corr()

# %%
df_combined_baseline
# Out:
#             object       mean  weighted_mean  standard_deviation     median  \
# 0     ZTF18abbrikh  16.104658      16.079719            0.275773  16.110229
# 1     ZTF18aayofec  18.284940      17.232688            1.134601  18.868792
# 2     ZTF18aazfeju  15.171564      15.159009            0.181192  15.170848
# 3     ZTF18adjmyuq  15.976566      15.951539            0.214719  15.986678
# 4     ZTF20aanlcpd  18.650733      18.591911            0.214695  18.737732
# ...            ...        ...            ...                 ...        ...
# 1566  ZTF18abrrzeq  17.364388      17.335678            0.202778  17.408093
# 1567  ZTF18abjartz  16.276459      16.266405            0.187004  16.227710
# 1568  ZTF18abareij  16.179850      16.174791            0.140425  16.186563
# 1569  ZTF18abdktfs  15.533986      15.508577            0.411432  15.650111
# 1570  ZTF18abkjoey  16.890158      16.310514            1.169690  16.960255
#
#       amplitude  beyond_1_std     cusum  inter_percentile_range_10  kurtosis  \
# 0      0.691751      0.280480  0.223662                   0.665586 -0.943915
# 1      2.270712      0.361605  0.292773                   3.069963 -0.884689
# 2      0.650220      0.278806  0.187474                   0.406838 -0.250757
# 3      0.833680      0.386419  0.210536                   0.489179 -0.491081
# 4      0.522768      0.343625  0.425178                   0.569489 -0.806568
# ...         ...           ...       ...                        ...       ...
# 1566   0.858205      0.316740  0.308967                   0.570480  1.000957
# 1567   0.883832      0.314081  0.224566                   0.520515  0.647527
# 1568   0.568323      0.325492  0.163742                   0.365974  0.630992
# 1569   1.141420      0.320052  0.170971                   1.042116 -0.451241
# 1570   2.367967      0.329588  0.322346                   2.960732 -0.869925
#
#       ...  magnitude_percentage_ratio_20_10  maximum_slope  \
# 0     ...                          0.744480     651.894741
# 1     ...                          0.634668     551.500895
# 2     ...                          0.784730     739.187643
# 3     ...                          0.867378     706.746592
# 4     ...                          0.710384     369.599590
# ...   ...                               ...            ...
# 1566  ...                          0.488363     583.165123
# 1567  ...                          0.595561     333.049997
# 1568  ...                          0.642558    1108.935013
# 1569  ...                          0.677081    1797.235556
# 1570  ...                          0.751547     209.244904
#
#       median_absolute_deviation  median_buffer_range_percentage_10  \
# 0                      0.228996                           0.087176
# 1                      0.657377                           0.363324
# 2                      0.147596                           0.161692
# 3                      0.187393                           0.219078
# 4                      0.083839                           0.367639
# ...                         ...                                ...
# 1566                   0.087821                           0.497265
# 1567                   0.083885                           0.509351
# 1568                   0.080962                           0.441466
# 1569                   0.328679                           0.251470
# 1570                   1.081364                           0.072766
#
#       percent_amplitude  mean_variance  anderson_darling_normal         chi2  \
# 0              0.706575       0.017124                34.641464   286.046599
# 1              3.056760       0.062051                70.756626   821.288483
# 2              0.830567       0.011943                33.423127    78.529824
# 3              1.047107       0.013440                36.218583   195.238960
# 4              0.566807       0.011511                90.759503    27.144515
# ...                 ...            ...                      ...          ...
# 1566           1.072328       0.011678                35.709418    76.886510
# 1567           1.255658       0.011489                49.548507    76.328801
# 1568           0.653109       0.008679                27.279678    59.177617
# 1569           1.153958       0.026486                12.211495   423.258197
# 1570           3.058878       0.069253                69.466126  2610.367548
#
#           skew  stetson_K
# 0    -0.114433   0.886735
# 1    -0.586882   0.903019
# 2     0.226995   0.844526
# 3     0.065449   0.856172
# 4    -0.597097   0.904202
# ...        ...        ...
# 1566  0.121359   0.795542
# 1567  0.526362   0.772414
# 1568 -0.531466   0.728493
# 1569 -0.130320   0.852060
# 1570 -0.504360   0.854925
#
# [1571 rows x 27 columns]

# %%
features_combined_baseline
# Out:
#            mean  weighted_mean  standard_deviation     median  amplitude  \
# 0     16.104658      16.079719            0.275773  16.110229   0.691751
# 1     18.284940      17.232688            1.134601  18.868792   2.270712
# 2     15.171564      15.159009            0.181192  15.170848   0.650220
# 3     15.976566      15.951539            0.214719  15.986678   0.833680
# 4     18.650733      18.591911            0.214695  18.737732   0.522768
# ...         ...            ...                 ...        ...        ...
# 1566  17.364388      17.335678            0.202778  17.408093   0.858205
# 1567  16.276459      16.266405            0.187004  16.227710   0.883832
# 1568  16.179850      16.174791            0.140425  16.186563   0.568323
# 1569  15.533986      15.508577            0.411432  15.650111   1.141420
# 1570  16.890158      16.310514            1.169690  16.960255   2.367967
#
#       beyond_1_std     cusum  inter_percentile_range_10  kurtosis  \
# 0         0.280480  0.223662                   0.665586 -0.943915
# 1         0.361605  0.292773                   3.069963 -0.884689
# 2         0.278806  0.187474                   0.406838 -0.250757
# 3         0.386419  0.210536                   0.489179 -0.491081
# 4         0.343625  0.425178                   0.569489 -0.806568
# ...            ...       ...                        ...       ...
# 1566      0.316740  0.308967                   0.570480  1.000957
# 1567      0.314081  0.224566                   0.520515  0.647527
# 1568      0.325492  0.163742                   0.365974  0.630992
# 1569      0.320052  0.170971                   1.042116 -0.451241
# 1570      0.329588  0.322346                   2.960732 -0.869925
#
#       linear_trend  ...  magnitude_percentage_ratio_20_10  maximum_slope  \
# 0         0.000123  ...                          0.744480     651.894741
# 1         0.000169  ...                          0.634668     551.500895
# 2         0.000055  ...                          0.784730     739.187643
# 3        -0.000076  ...                          0.867378     706.746592
# 4         0.000194  ...                          0.710384     369.599590
# ...            ...  ...                               ...            ...
# 1566      0.000145  ...                          0.488363     583.165123
# 1567     -0.000060  ...                          0.595561     333.049997
# 1568     -0.000027  ...                          0.642558    1108.935013
# 1569      0.000090  ...                          0.677081    1797.235556
# 1570      0.000841  ...                          0.751547     209.244904
#
#       median_absolute_deviation  median_buffer_range_percentage_10  \
# 0                      0.228996                           0.087176
# 1                      0.657377                           0.363324
# 2                      0.147596                           0.161692
# 3                      0.187393                           0.219078
# 4                      0.083839                           0.367639
# ...                         ...                                ...
# 1566                   0.087821                           0.497265
# 1567                   0.083885                           0.509351
# 1568                   0.080962                           0.441466
# 1569                   0.328679                           0.251470
# 1570                   1.081364                           0.072766
#
#       percent_amplitude  mean_variance  anderson_darling_normal         chi2  \
# 0              0.706575       0.017124                34.641464   286.046599
# 1              3.056760       0.062051                70.756626   821.288483
# 2              0.830567       0.011943                33.423127    78.529824
# 3              1.047107       0.013440                36.218583   195.238960
# 4              0.566807       0.011511                90.759503    27.144515
# ...                 ...            ...                      ...          ...
# 1566           1.072328       0.011678                35.709418    76.886510
# 1567           1.255658       0.011489                49.548507    76.328801
# 1568           0.653109       0.008679                27.279678    59.177617
# 1569           1.153958       0.026486                12.211495   423.258197
# 1570           3.058878       0.069253                69.466126  2610.367548
#
#           skew  stetson_K
# 0    -0.114433   0.886735
# 1    -0.586882   0.903019
# 2     0.226995   0.844526
# 3     0.065449   0.856172
# 4    -0.597097   0.904202
# ...        ...        ...
# 1566  0.121359   0.795542
# 1567  0.526362   0.772414
# 1568 -0.531466   0.728493
# 1569 -0.130320   0.852060
# 1570 -0.504360   0.854925
#
# [1571 rows x 26 columns]

# %%
corr_combined_baseline
# Out:
#                                        mean  weighted_mean  \
# mean                               1.000000       0.975702
# weighted_mean                      0.975702       1.000000
# standard_deviation                 0.337912       0.164851
# median                             0.991679       0.962911
# amplitude                          0.269312       0.109169
# beyond_1_std                       0.108596       0.087570
# cusum                              0.064146       0.061213
# inter_percentile_range_10          0.327027       0.157644
# kurtosis                          -0.166912      -0.157623
# linear_trend                       0.027534       0.024023
# linear_trend_sigma                 0.301665       0.198050
# linear_trend_noise                 0.324289       0.154711
# linear_fit_slope                   0.000874       0.002048
# linear_fit_slope_sigma             0.361779       0.345471
# linear_fit_reduced_chi2           -0.044192      -0.144579
# magnitude_percentage_ratio_40_5    0.030747       0.021453
# magnitude_percentage_ratio_20_10   0.018959       0.007902
# maximum_slope                     -0.026170      -0.061966
# median_absolute_deviation          0.287106       0.130473
# median_buffer_range_percentage_10 -0.269897      -0.231826
# percent_amplitude                  0.221502       0.068275
# mean_variance                      0.252839       0.085952
# anderson_darling_normal           -0.019413      -0.046891
# chi2                              -0.055595      -0.154523
# skew                              -0.284220      -0.273158
# stetson_K                          0.254731       0.189893
#
#                                    standard_deviation    median  amplitude  \
# mean                                         0.337912  0.991679   0.269312
# weighted_mean                                0.164851  0.962911   0.109169
# standard_deviation                           1.000000  0.341706   0.899983
# median                                       0.341706  1.000000   0.271495
# amplitude                                    0.899983  0.271495   1.000000
# beyond_1_std                                 0.181610  0.112847   0.000093
# cusum                                        0.000963  0.063280  -0.109066
# inter_percentile_range_10                    0.991379  0.331515   0.883939
# kurtosis                                    -0.165239 -0.164068   0.031849
# linear_trend                                 0.025970  0.063393   0.029694
# linear_trend_sigma                           0.581825  0.302941   0.521484
# linear_trend_noise                           0.985804  0.329868   0.902749
# linear_fit_slope                             0.046524  0.037992   0.056885
# linear_fit_slope_sigma                       0.123618  0.359816   0.110913
# linear_fit_reduced_chi2                      0.727627 -0.019301   0.658456
# magnitude_percentage_ratio_40_5              0.037042  0.032414  -0.062048
# magnitude_percentage_ratio_20_10             0.043141  0.021525  -0.062450
# maximum_slope                                0.132073 -0.026282   0.221270
# median_absolute_deviation                    0.902986  0.289028   0.770794
# median_buffer_range_percentage_10           -0.357232 -0.268527  -0.072156
# percent_amplitude                            0.825831  0.224493   0.960166
# mean_variance                                0.993109  0.256952   0.893441
# anderson_darling_normal                      0.158244 -0.021149   0.130234
# chi2                                         0.725380 -0.028014   0.642643
# skew                                        -0.163505 -0.311267  -0.053842
# stetson_K                                    0.376552  0.271189   0.180662
#
#                                    beyond_1_std     cusum  \
# mean                                   0.108596  0.064146
# weighted_mean                          0.087570  0.061213
# standard_deviation                     0.181610  0.000963
# median                                 0.112847  0.063280
# amplitude                              0.000093 -0.109066
# beyond_1_std                           1.000000  0.363094
# cusum                                  0.363094  1.000000
# inter_percentile_range_10              0.210750 -0.007756
# kurtosis                              -0.324663 -0.073245
# linear_trend                           0.018024  0.008537
# linear_trend_sigma                     0.048419 -0.020697
# linear_trend_noise                     0.135840 -0.079440
# linear_fit_slope                       0.006901 -0.005368
# linear_fit_slope_sigma                -0.033791 -0.040221
# linear_fit_reduced_chi2                0.102607 -0.052137
# magnitude_percentage_ratio_40_5        0.382989  0.513984
# magnitude_percentage_ratio_20_10       0.575161  0.515409
# maximum_slope                         -0.008386 -0.077507
# median_absolute_deviation              0.391524  0.070640
# median_buffer_range_percentage_10     -0.588917 -0.256851
# percent_amplitude                     -0.098176 -0.098789
# mean_variance                          0.183551 -0.006385
# anderson_darling_normal               -0.284256 -0.014699
# chi2                                   0.134902 -0.005351
# skew                                  -0.301012 -0.103256
# stetson_K                              0.612884  0.445575
#
#                                    inter_percentile_range_10  kurtosis  \
# mean                                                0.327027 -0.166912
# weighted_mean                                       0.157644 -0.157623
# standard_deviation                                  0.991379 -0.165239
# median                                              0.331515 -0.164068
# amplitude                                           0.883939  0.031849
# beyond_1_std                                        0.210750 -0.324663
# cusum                                              -0.007756 -0.073245
# inter_percentile_range_10                           1.000000 -0.175126
# kurtosis                                           -0.175126  1.000000
# linear_trend                                        0.034922 -0.001092
# linear_trend_sigma                                  0.571325 -0.097374
# linear_trend_noise                                  0.984170 -0.160584
# linear_fit_slope                                    0.066175 -0.005658
# linear_fit_slope_sigma                              0.108650 -0.038618
# linear_fit_reduced_chi2                             0.728621 -0.097609
# magnitude_percentage_ratio_40_5                     0.004943  0.000593
# magnitude_percentage_ratio_20_10                    0.019227 -0.022243
# maximum_slope                                       0.122433  0.086827
# median_absolute_deviation                           0.899415 -0.160388
# median_buffer_range_percentage_10                  -0.363343  0.514668
# percent_amplitude                                   0.800317  0.118019
# mean_variance                                       0.985971 -0.162531
# anderson_darling_normal                             0.121548  0.047781
# chi2                                                0.722014 -0.098655
# skew                                               -0.174376  0.513113
# stetson_K                                           0.387470 -0.414322
#
#                                    linear_trend  ...  \
# mean                                   0.027534  ...
# weighted_mean                          0.024023  ...
# standard_deviation                     0.025970  ...
# median                                 0.063393  ...
# amplitude                              0.029694  ...
# beyond_1_std                           0.018024  ...
# cusum                                  0.008537  ...
# inter_percentile_range_10              0.034922  ...
# kurtosis                              -0.001092  ...
# linear_trend                           1.000000  ...
# linear_trend_sigma                     0.045578  ...
# linear_trend_noise                     0.041544  ...
# linear_fit_slope                       0.843172  ...
# linear_fit_slope_sigma                 0.028182  ...
# linear_fit_reduced_chi2                0.043322  ...
# magnitude_percentage_ratio_40_5        0.009426  ...
# magnitude_percentage_ratio_20_10      -0.008386  ...
# maximum_slope                         -0.021800  ...
# median_absolute_deviation              0.061882  ...
# median_buffer_range_percentage_10     -0.028372  ...
# percent_amplitude                      0.006732  ...
# mean_variance                          0.017917  ...
# anderson_darling_normal               -0.052762  ...
# chi2                                   0.022322  ...
# skew                                  -0.080037  ...
# stetson_K                              0.029572  ...
#
#                                    magnitude_percentage_ratio_20_10  \
# mean                                                       0.018959
# weighted_mean                                              0.007902
# standard_deviation                                         0.043141
# median                                                     0.021525
# amplitude                                                 -0.062450
# beyond_1_std                                               0.575161
# cusum                                                      0.515409
# inter_percentile_range_10                                  0.019227
# kurtosis                                                  -0.022243
# linear_trend                                              -0.008386
# linear_trend_sigma                                        -0.032876
# linear_trend_noise                                        -0.026578
# linear_fit_slope                                          -0.032083
# linear_fit_slope_sigma                                    -0.027871
# linear_fit_reduced_chi2                                   -0.008794
# magnitude_percentage_ratio_40_5                            0.696973
# magnitude_percentage_ratio_20_10                           1.000000
# maximum_slope                                              0.017860
# median_absolute_deviation                                  0.210831
# median_buffer_range_percentage_10                         -0.439495
# percent_amplitude                                         -0.070448
# mean_variance                                              0.043149
# anderson_darling_normal                                   -0.150285
# chi2                                                       0.037598
# skew                                                      -0.101622
# stetson_K                                                  0.605939
#
#                                    maximum_slope  median_absolute_deviation  \
# mean                                   -0.026170                   0.287106
# weighted_mean                          -0.061966                   0.130473
# standard_deviation                      0.132073                   0.902986
# median                                 -0.026282                   0.289028
# amplitude                               0.221270                   0.770794
# beyond_1_std                           -0.008386                   0.391524
# cusum                                  -0.077507                   0.070640
# inter_percentile_range_10               0.122433                   0.899415
# kurtosis                                0.086827                  -0.160388
# linear_trend                           -0.021800                   0.061882
# linear_trend_sigma                      0.044584                   0.501465
# linear_trend_noise                      0.123230                   0.869424
# linear_fit_slope                       -0.021227                   0.026785
# linear_fit_slope_sigma                  0.027558                   0.097946
# linear_fit_reduced_chi2                 0.078137                   0.641758
# magnitude_percentage_ratio_40_5         0.005970                   0.220714
# magnitude_percentage_ratio_20_10        0.017860                   0.210831
# maximum_slope                           1.000000                   0.136188
# median_absolute_deviation               0.136188                   1.000000
# median_buffer_range_percentage_10       0.056933                  -0.469623
# percent_amplitude                       0.217446                   0.652125
# mean_variance                           0.132748                   0.900046
# anderson_darling_normal                -0.024654                   0.007331
# chi2                                    0.077425                   0.660777
# skew                                   -0.001930                  -0.166671
# stetson_K                              -0.030698                   0.440073
#
#                                    median_buffer_range_percentage_10  \
# mean                                                       -0.269897
# weighted_mean                                              -0.231826
# standard_deviation                                         -0.357232
# median                                                     -0.268527
# amplitude                                                  -0.072156
# beyond_1_std                                               -0.588917
# cusum                                                      -0.256851
# inter_percentile_range_10                                  -0.363343
# kurtosis                                                    0.514668
# linear_trend                                               -0.028372
# linear_trend_sigma                                         -0.218561
# linear_trend_noise                                         -0.321182
# linear_fit_slope                                            0.010839
# linear_fit_slope_sigma                                     -0.094798
# linear_fit_reduced_chi2                                    -0.202194
# magnitude_percentage_ratio_40_5                            -0.483859
# magnitude_percentage_ratio_20_10                           -0.439495
# maximum_slope                                               0.056933
# median_absolute_deviation                                  -0.469623
# median_buffer_range_percentage_10                           1.000000
# percent_amplitude                                           0.026004
# mean_variance                                              -0.350689
# anderson_darling_normal                                     0.201008
# chi2                                                       -0.221949
# skew                                                        0.369758
# stetson_K                                                  -0.710692
#
#                                    percent_amplitude  mean_variance  \
# mean                                        0.221502       0.252839
# weighted_mean                               0.068275       0.085952
# standard_deviation                          0.825831       0.993109
# median                                      0.224493       0.256952
# amplitude                                   0.960166       0.893441
# beyond_1_std                               -0.098176       0.183551
# cusum                                      -0.098789      -0.006385
# inter_percentile_range_10                   0.800317       0.985971
# kurtosis                                    0.118019      -0.162531
# linear_trend                                0.006732       0.017917
# linear_trend_sigma                          0.485185       0.563759
# linear_trend_noise                          0.832012       0.980519
# linear_fit_slope                            0.032362       0.044983
# linear_fit_slope_sigma                      0.101637       0.091083
# linear_fit_reduced_chi2                     0.611771       0.780100
# magnitude_percentage_ratio_40_5            -0.072509       0.034637
# magnitude_percentage_ratio_20_10           -0.070448       0.043149
# maximum_slope                               0.217446       0.132748
# median_absolute_deviation                   0.652125       0.900046
# median_buffer_range_percentage_10           0.026004      -0.350689
# percent_amplitude                           1.000000       0.819101
# mean_variance                               0.819101       1.000000
# anderson_darling_normal                     0.198648       0.165181
# chi2                                        0.590053       0.781017
# skew                                        0.008247      -0.153616
# stetson_K                                   0.117100       0.361815
#
#                                    anderson_darling_normal      chi2  \
# mean                                             -0.019413 -0.055595
# weighted_mean                                    -0.046891 -0.154523
# standard_deviation                                0.158244  0.725380
# median                                           -0.021149 -0.028014
# amplitude                                         0.130234  0.642643
# beyond_1_std                                     -0.284256  0.134902
# cusum                                            -0.014699 -0.005351
# inter_percentile_range_10                         0.121548  0.722014
# kurtosis                                          0.047781 -0.098655
# linear_trend                                     -0.052762  0.022322
# linear_trend_sigma                               -0.040951  0.343284
# linear_trend_noise                                0.138708  0.722393
# linear_fit_slope                                 -0.020589  0.073009
# linear_fit_slope_sigma                           -0.125885 -0.042955
# linear_fit_reduced_chi2                           0.164921  0.977222
# magnitude_percentage_ratio_40_5                  -0.064992  0.028606
# magnitude_percentage_ratio_20_10                 -0.150285  0.037598
# maximum_slope                                    -0.024654  0.077425
# median_absolute_deviation                         0.007331  0.660777
# median_buffer_range_percentage_10                 0.201008 -0.221949
# percent_amplitude                                 0.198648  0.590053
# mean_variance                                     0.165181  0.781017
# anderson_darling_normal                           1.000000  0.171096
# chi2                                              0.171096  1.000000
# skew                                              0.181890 -0.151240
# stetson_K                                        -0.108049  0.229659
#
#                                        skew  stetson_K
# mean                              -0.284220   0.254731
# weighted_mean                     -0.273158   0.189893
# standard_deviation                -0.163505   0.376552
# median                            -0.311267   0.271189
# amplitude                         -0.053842   0.180662
# beyond_1_std                      -0.301012   0.612884
# cusum                             -0.103256   0.445575
# inter_percentile_range_10         -0.174376   0.387470
# kurtosis                           0.513113  -0.414322
# linear_trend                      -0.080037   0.029572
# linear_trend_sigma                -0.079565   0.196395
# linear_trend_noise                -0.161732   0.333574
# linear_fit_slope                  -0.097323   0.029658
# linear_fit_slope_sigma            -0.055818   0.019658
# linear_fit_reduced_chi2           -0.156570   0.192557
# magnitude_percentage_ratio_40_5   -0.075368   0.559135
# magnitude_percentage_ratio_20_10  -0.101622   0.605939
# maximum_slope                     -0.001930  -0.030698
# median_absolute_deviation         -0.166671   0.440073
# median_buffer_range_percentage_10  0.369758  -0.710692
# percent_amplitude                  0.008247   0.117100
# mean_variance                     -0.153616   0.361815
# anderson_darling_normal            0.181890  -0.108049
# chi2                              -0.151240   0.229659
# skew                               1.000000  -0.243959
# stetson_K                         -0.243959   1.000000
#
# [26 rows x 26 columns]

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(corr_combined_baseline, cmap='coolwarm', center=0)
plt.title('Feature–Feature Correlation (baseline  matrix)')
plt.tight_layout()
plt.show()

# %%
neg_files = sorted(glob.glob("negative_subset_*.parquet"))

# %%
print (neg_files)
# Out:
# ['negative_subset_1.parquet', 'negative_subset_10.parquet', 'negative_subset_11.parquet', 'negative_subset_2.parquet', 'negative_subset_3.parquet', 'negative_subset_4.parquet', 'negative_subset_5.parquet', 'negative_subset_6.parquet', 'negative_subset_7.parquet', 'negative_subset_8.parquet', 'negative_subset_9.parquet', 'negative_subset_noise_points.parquet']

# %%
# Store sampled dataframes
sampled_list = []
#print (sampled_list)

# %%
for f in neg_files:
    df = pd.read_parquet(f)
# Randomly sample 35 rows (or all if file has <10)
    #n = min(100, len(df))
    #n=max(100, len(df))
    n=len(df)
    print(n)
    sampled = df.sample(n, random_state=42)
    sampled_list.append(sampled)
    #print(f"Sampled {n} rows from {f}"
combined_df = pd.concat(sampled_list, ignore_index=True)
# Shuffle the combined data 
combined_df = combined_df.sample(frac=1, random_state=42).reset_index(drop=True)
# Save to new parquet
combined_df.to_parquet("negative_combined_all.parquet", index=False)
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 366

# %%
import pandas as pd

# Load both files
df_parquet = pd.read_parquet("negative_combined_all.parquet")
df_csv = pd.read_csv("positive_100_elements.csv")
combined = pd.concat([df_parquet, df_csv], ignore_index=True)
combined.to_parquet("subset of baseline with allneg & pos.parquet", index=False)

print("Combined and shuffled dataset saved as 'subset of baseline with allneg & pos.parquet'")
print("Total rows:", len(combined))
# Out:
# Combined and shuffled dataset saved as 'subset of baseline with allneg & pos.parquet'
# Total rows: 1566

# %%
df_parquet
# Out:
#             object       mean  weighted_mean  standard_deviation     median  \
# 0     ZTF18abaixud  15.254409      15.002403            1.215253  15.146256
# 1     ZTF18abgybwn  15.496750      15.321343            0.972581  15.306947
# 2     ZTF18abarcsa  18.507061      17.241269            1.119125  18.699999
# 3     ZTF18abaqbzy  17.768075      17.683088            0.330559  17.718870
# 4     ZTF18aayofec  18.284940      17.232688            1.134601  18.868792
# ...            ...        ...            ...                 ...        ...
# 1461  ZTF18aawkneh  16.401796      15.938038            1.083485  16.321598
# 1462  ZTF18aazuxop  16.380364      15.966092            1.088220  16.047491
# 1463  ZTF18abchmws  18.288208      16.905592            1.208226  18.695475
# 1464  ZTF18abyvokd  15.188215      15.182290            0.171112  15.251856
# 1465  ZTF18aazuyen  16.896426      16.425233            1.040702  16.746800
#
#       amplitude  beyond_1_std     cusum  inter_percentile_range_10  kurtosis  \
# 0      2.050862      0.488313  0.223234                   3.376298 -1.217323
# 1      2.283591      0.328829  0.179713                   2.647067 -0.484464
# 2      2.377338      0.311485  0.185830                   3.209219  0.186609
# 3      0.903527      0.263965  0.314342                   0.870911  0.569928
# 4      2.270712      0.361605  0.292773                   3.069963 -0.884689
# ...         ...           ...       ...                        ...       ...
# 1461   2.392891      0.534252  0.229053                   2.559660 -1.410349
# 1462   2.104604      0.408098  0.247785                   2.893981 -0.876541
# 1463   2.365181      0.326087  0.237308                   3.399606  0.010482
# 1464   1.324175      0.364099  0.419901                   0.412816  4.285011
# 1465   2.826868      0.318122  0.192735                   2.940496  0.032291
#
#       ...  maximum_slope  median_absolute_deviation  \
# 0     ...     432.244277                   1.244574
# 1     ...     384.749161                   0.645160
# 2     ...    1667.142417                   0.492254
# 3     ...     201.508709                   0.246017
# 4     ...     551.500895                   0.657377
# ...   ...            ...                        ...
# 1461  ...     933.561122                   1.025895
# 1462  ...     985.465837                   0.857139
# 1463  ...     568.612742                   0.651842
# 1464  ...     669.491346                   0.104839
# 1465  ...    1653.950847                   0.562969
#
#       median_buffer_range_percentage_10  percent_amplitude  mean_variance  \
# 0                              0.230575           2.093864       0.079666
# 1                              0.274131           2.299208       0.062760
# 2                              0.351821           2.984475       0.060470
# 3                              0.319277           1.405636       0.018604
# 4                              0.363324           3.056760       0.062051
# ...                                 ...                ...            ...
# 1461                           0.065525           3.144646       0.066059
# 1462                           0.082905           2.708074       0.066434
# 1463                           0.155468           3.556677       0.066066
# 1464                           0.587524           1.661679       0.011266
# 1465                           0.242725           3.439516       0.061593
#
#       anderson_darling_normal         chi2      skew  stetson_K  cluster
# 0                   43.448047  4233.705337 -0.243635   0.850254       -1
# 1                   12.928204  2106.147502  0.084827   0.788825        6
# 2                   95.461682  1419.796697 -1.047052   0.922748       -1
# 3                   72.471907   115.745384  1.108105   0.812953        1
# 4                   70.756626   821.288483 -0.586882   0.903019        9
# ...                       ...          ...       ...        ...      ...
# 1461               125.979098  2286.627583  0.231154   0.944926       -1
# 1462                34.521670  1536.934653  0.494570   0.872487       -1
# 1463                61.388720  1384.590809 -1.003587   0.908982        9
# 1464                53.667911    47.701884 -0.691866   0.867262       -1
# 1465                13.837582  1658.775944  0.380096   0.842605       -1
#
# [1466 rows x 28 columns]

# %%
df_parquet_1=pd.read_parquet('subset of baseline with allneg & pos.parquet')

# %%
df_parquet_1
# Out:
#             object       mean  weighted_mean  standard_deviation     median  \
# 0     ZTF18abaixud  15.254409      15.002403            1.215253  15.146256
# 1     ZTF18abgybwn  15.496750      15.321343            0.972581  15.306947
# 2     ZTF18abarcsa  18.507061      17.241269            1.119125  18.699999
# 3     ZTF18abaqbzy  17.768075      17.683088            0.330559  17.718870
# 4     ZTF18aayofec  18.284940      17.232688            1.134601  18.868792
# ...            ...        ...            ...                 ...        ...
# 1561      V418 Gem  16.905293      16.891739            0.130254  16.905872
# 1562      V677 And  19.227544      18.342081            0.989385  19.060970
# 1563     V2306 Cyg  15.869141      15.860906            0.180194  15.848884
# 1564        IL Leo  18.458933      17.494483            0.926653  18.622186
# 1565           Oph  15.821274      15.817911            0.129693  15.831488
#
#       amplitude  beyond_1_std     cusum  inter_percentile_range_10   kurtosis  \
# 0      2.050862      0.488313  0.223234                   3.376298  -1.217323
# 1      2.283591      0.328829  0.179713                   2.647067  -0.484464
# 2      2.377338      0.311485  0.185830                   3.209219   0.186609
# 3      0.903527      0.263965  0.314342                   0.870911   0.569928
# 4      2.270712      0.361605  0.292773                   3.069963  -0.884689
# ...         ...           ...       ...                        ...        ...
# 1561   0.641553      0.319716  0.146000                   0.328610   0.831722
# 1562   2.745060      0.425414  0.429222                   2.542357  -1.123188
# 1563   1.344455      0.201835  0.180301                   0.363799  34.378112
# 1564   1.716861      0.440613  0.290478                   2.460330  -1.174519
# 1565   0.456778      0.285256  0.165112                   0.307883   1.460111
#
#       ...  maximum_slope  median_absolute_deviation  \
# 0     ...     432.244277                   1.244574
# 1     ...     384.749161                   0.645160
# 2     ...    1667.142417                   0.492254
# 3     ...     201.508709                   0.246017
# 4     ...     551.500895                   0.657377
# ...   ...            ...                        ...
# 1561  ...     679.331641                   0.087836
# 1562  ...     789.621964                   0.868201
# 1563  ...    2868.198512                   0.094182
# 1564  ...     848.642852                   0.697933
# 1565  ...     319.386942                   0.083125
#
#       median_buffer_range_percentage_10  percent_amplitude  mean_variance  \
# 0                              0.230575           2.093864       0.079666
# 1                              0.274131           2.299208       0.062760
# 2                              0.351821           2.984475       0.060470
# 3                              0.319277           1.405636       0.018604
# 4                              0.363324           3.056760       0.062051
# ...                                 ...                ...            ...
# 1561                           0.388099           0.741325       0.007705
# 1562                           0.143646           2.862148       0.051457
# 1563                           0.677982           2.232877       0.011355
# 1564                           0.159004           1.914783       0.050201
# 1565                           0.283120           0.603597       0.008197
#
#       anderson_darling_normal         chi2      skew  stetson_K  cluster
# 0                   43.448047  4233.705337 -0.243635   0.850254     -1.0
# 1                   12.928204  2106.147502  0.084827   0.788825      6.0
# 2                   95.461682  1419.796697 -1.047052   0.922748     -1.0
# 3                   72.471907   115.745384  1.108105   0.812953      1.0
# 4                   70.756626   821.288483 -0.586882   0.903019      9.0
# ...                       ...          ...       ...        ...      ...
# 1561                 0.198451    59.169751 -0.083027   0.789198      NaN
# 1562                16.202306   199.179353  0.269137   0.853870      NaN
# 1563                19.465335    79.962911  3.661152   0.732837      NaN
# 1564                10.833990   352.659253 -0.240478   0.948347      NaN
# 1565                 5.386825    57.958513 -0.836126   0.771527      NaN
#
# [1566 rows x 28 columns]

# %%
df_combined_baseline_subset_all = pd.read_parquet("subset of baseline with allneg & pos.parquet")
features_combined_baseline_subset_all = df_combined_baseline_subset_all .drop(columns=['object','cluster'])#errors='ignore')
#features_combined_baseline_subset_all_numeric = features_combined_baseline_subset_all.select_dtypes(include='number')
corr_combined_baseline_subset_all = features_combined_baseline_subset_all.corr()

# %%
features_combined_baseline_subset_all
# Out:
#            mean  weighted_mean  standard_deviation     median  amplitude  \
# 0     15.254409      15.002403            1.215253  15.146256   2.050862
# 1     15.496750      15.321343            0.972581  15.306947   2.283591
# 2     18.507061      17.241269            1.119125  18.699999   2.377338
# 3     17.768075      17.683088            0.330559  17.718870   0.903527
# 4     18.284940      17.232688            1.134601  18.868792   2.270712
# ...         ...            ...                 ...        ...        ...
# 1561  16.905293      16.891739            0.130254  16.905872   0.641553
# 1562  19.227544      18.342081            0.989385  19.060970   2.745060
# 1563  15.869141      15.860906            0.180194  15.848884   1.344455
# 1564  18.458933      17.494483            0.926653  18.622186   1.716861
# 1565  15.821274      15.817911            0.129693  15.831488   0.456778
#
#       beyond_1_std     cusum  inter_percentile_range_10   kurtosis  \
# 0         0.488313  0.223234                   3.376298  -1.217323
# 1         0.328829  0.179713                   2.647067  -0.484464
# 2         0.311485  0.185830                   3.209219   0.186609
# 3         0.263965  0.314342                   0.870911   0.569928
# 4         0.361605  0.292773                   3.069963  -0.884689
# ...            ...       ...                        ...        ...
# 1561      0.319716  0.146000                   0.328610   0.831722
# 1562      0.425414  0.429222                   2.542357  -1.123188
# 1563      0.201835  0.180301                   0.363799  34.378112
# 1564      0.440613  0.290478                   2.460330  -1.174519
# 1565      0.285256  0.165112                   0.307883   1.460111
#
#       linear_trend  ...  magnitude_percentage_ratio_20_10  maximum_slope  \
# 0         0.000145  ...                          0.823933     432.244277
# 1         0.000138  ...                          0.671567     384.749161
# 2        -0.000154  ...                          0.557956    1667.142417
# 3        -0.000117  ...                          0.607360     201.508709
# 4         0.000169  ...                          0.634668     551.500895
# ...            ...  ...                               ...            ...
# 1561      0.000015  ...                          0.673249     679.331641
# 1562      0.001677  ...                          0.796496     789.621964
# 1563     -0.000084  ...                          0.628867    2868.198512
# 1564     -0.000023  ...                          0.813309     848.642852
# 1565     -0.000033  ...                          0.674872     319.386942
#
#       median_absolute_deviation  median_buffer_range_percentage_10  \
# 0                      1.244574                           0.230575
# 1                      0.645160                           0.274131
# 2                      0.492254                           0.351821
# 3                      0.246017                           0.319277
# 4                      0.657377                           0.363324
# ...                         ...                                ...
# 1561                   0.087836                           0.388099
# 1562                   0.868201                           0.143646
# 1563                   0.094182                           0.677982
# 1564                   0.697933                           0.159004
# 1565                   0.083125                           0.283120
#
#       percent_amplitude  mean_variance  anderson_darling_normal         chi2  \
# 0              2.093864       0.079666                43.448047  4233.705337
# 1              2.299208       0.062760                12.928204  2106.147502
# 2              2.984475       0.060470                95.461682  1419.796697
# 3              1.405636       0.018604                72.471907   115.745384
# 4              3.056760       0.062051                70.756626   821.288483
# ...                 ...            ...                      ...          ...
# 1561           0.741325       0.007705                 0.198451    59.169751
# 1562           2.862148       0.051457                16.202306   199.179353
# 1563           2.232877       0.011355                19.465335    79.962911
# 1564           1.914783       0.050201                10.833990   352.659253
# 1565           0.603597       0.008197                 5.386825    57.958513
#
#           skew  stetson_K
# 0    -0.243635   0.850254
# 1     0.084827   0.788825
# 2    -1.047052   0.922748
# 3     1.108105   0.812953
# 4    -0.586882   0.903019
# ...        ...        ...
# 1561 -0.083027   0.789198
# 1562  0.269137   0.853870
# 1563  3.661152   0.732837
# 1564 -0.240478   0.948347
# 1565 -0.836126   0.771527
#
# [1566 rows x 26 columns]

# %%
corr_combined_baseline_subset_all
# Out:
#                                        mean  weighted_mean  \
# mean                               1.000000       0.969474
# weighted_mean                      0.969474       1.000000
# standard_deviation                 0.449837       0.271277
# median                             0.987364       0.945014
# amplitude                          0.404052       0.240139
# beyond_1_std                       0.257316       0.182035
# cusum                              0.014580      -0.007078
# inter_percentile_range_10          0.446489       0.272261
# kurtosis                          -0.273154      -0.255310
# linear_trend                      -0.074195      -0.026971
# linear_trend_sigma                 0.355026       0.257008
# linear_trend_noise                 0.447532       0.274493
# linear_fit_slope                   0.013708       0.041810
# linear_fit_slope_sigma             0.364182       0.375373
# linear_fit_reduced_chi2           -0.061531      -0.167046
# magnitude_percentage_ratio_40_5   -0.021550      -0.046446
# magnitude_percentage_ratio_20_10   0.019458      -0.026428
# maximum_slope                     -0.004793      -0.035192
# median_absolute_deviation          0.374020       0.208282
# median_buffer_range_percentage_10 -0.348069      -0.278230
# percent_amplitude                  0.351793       0.194106
# mean_variance                      0.351480       0.177676
# anderson_darling_normal           -0.124223      -0.096992
# chi2                              -0.074063      -0.181147
# skew                              -0.420871      -0.385688
# stetson_K                          0.423412       0.314741
#
#                                    standard_deviation    median  amplitude  \
# mean                                         0.449837  0.987364   0.404052
# weighted_mean                                0.271277  0.945014   0.240139
# standard_deviation                           1.000000  0.468707   0.911001
# median                                       0.468707  1.000000   0.420517
# amplitude                                    0.911001  0.420517   1.000000
# beyond_1_std                                 0.454638  0.272000   0.311411
# cusum                                        0.049990  0.014909  -0.067109
# inter_percentile_range_10                    0.989175  0.465242   0.902261
# kurtosis                                    -0.318518 -0.266385  -0.135341
# linear_trend                                -0.087100 -0.064422  -0.073510
# linear_trend_sigma                           0.582502  0.360620   0.525847
# linear_trend_noise                           0.982804  0.467425   0.918904
# linear_fit_slope                             0.042474  0.027388   0.065580
# linear_fit_slope_sigma                       0.074037  0.355175   0.062492
# linear_fit_reduced_chi2                      0.679995 -0.015382   0.641602
# magnitude_percentage_ratio_40_5              0.062098 -0.015851  -0.024700
# magnitude_percentage_ratio_20_10             0.145493  0.034171   0.063224
# maximum_slope                                0.033102 -0.006867   0.108635
# median_absolute_deviation                    0.892925  0.390920   0.775651
# median_buffer_range_percentage_10           -0.551063 -0.356177  -0.340979
# percent_amplitude                            0.834917  0.370482   0.948371
# mean_variance                                0.991707  0.371197   0.901645
# anderson_darling_normal                     -0.163842 -0.135046  -0.228381
# chi2                                         0.686244 -0.024390   0.626130
# skew                                        -0.417721 -0.450475  -0.323894
# stetson_K                                    0.575349  0.455887   0.428554
#
#                                    beyond_1_std     cusum  \
# mean                                   0.257316  0.014580
# weighted_mean                          0.182035 -0.007078
# standard_deviation                     0.454638  0.049990
# median                                 0.272000  0.014909
# amplitude                              0.311411 -0.067109
# beyond_1_std                           1.000000  0.271752
# cusum                                  0.271752  1.000000
# inter_percentile_range_10              0.463803  0.022421
# kurtosis                              -0.365463  0.026952
# linear_trend                          -0.129783  0.034398
# linear_trend_sigma                     0.239751  0.022306
# linear_trend_noise                     0.404847 -0.043605
# linear_fit_slope                      -0.096402 -0.008220
# linear_fit_slope_sigma                 0.027204 -0.034429
# linear_fit_reduced_chi2                0.232040 -0.066786
# magnitude_percentage_ratio_40_5        0.372554  0.518853
# magnitude_percentage_ratio_20_10       0.560178  0.561254
# maximum_slope                          0.038465  0.007037
# median_absolute_deviation              0.616519  0.143853
# median_buffer_range_percentage_10     -0.717847 -0.253599
# percent_amplitude                      0.180067 -0.028671
# mean_variance                          0.449474  0.044807
# anderson_darling_normal               -0.507979 -0.099380
# chi2                                   0.272862  0.002689
# skew                                  -0.469788 -0.006888
# stetson_K                              0.693924  0.420359
#
#                                    inter_percentile_range_10  kurtosis  \
# mean                                                0.446489 -0.273154
# weighted_mean                                       0.272261 -0.255310
# standard_deviation                                  0.989175 -0.318518
# median                                              0.465242 -0.266385
# amplitude                                           0.902261 -0.135341
# beyond_1_std                                        0.463803 -0.365463
# cusum                                               0.022421  0.026952
# inter_percentile_range_10                           1.000000 -0.324033
# kurtosis                                           -0.324033  1.000000
# linear_trend                                       -0.072550  0.007847
# linear_trend_sigma                                  0.571242 -0.201088
# linear_trend_noise                                  0.985030 -0.316692
# linear_fit_slope                                    0.077989 -0.029983
# linear_fit_slope_sigma                              0.060991 -0.065252
# linear_fit_reduced_chi2                             0.682322 -0.188141
# magnitude_percentage_ratio_40_5                    -0.002616  0.090220
# magnitude_percentage_ratio_20_10                    0.092575  0.097879
# maximum_slope                                       0.017339  0.117384
# median_absolute_deviation                           0.870761 -0.270231
# median_buffer_range_percentage_10                  -0.534810  0.529230
# percent_amplitude                                   0.816137 -0.033591
# mean_variance                                       0.980921 -0.315322
# anderson_darling_normal                            -0.186253 -0.037964
# chi2                                                0.679093 -0.189328
# skew                                               -0.428116  0.620644
# stetson_K                                           0.570381 -0.377980
#
#                                    linear_trend  ...  \
# mean                                  -0.074195  ...
# weighted_mean                         -0.026971  ...
# standard_deviation                    -0.087100  ...
# median                                -0.064422  ...
# amplitude                             -0.073510  ...
# beyond_1_std                          -0.129783  ...
# cusum                                  0.034398  ...
# inter_percentile_range_10             -0.072550  ...
# kurtosis                               0.007847  ...
# linear_trend                           1.000000  ...
# linear_trend_sigma                    -0.025410  ...
# linear_trend_noise                    -0.071348  ...
# linear_fit_slope                       0.847909  ...
# linear_fit_slope_sigma                 0.007450  ...
# linear_fit_reduced_chi2               -0.001316  ...
# magnitude_percentage_ratio_40_5        0.059624  ...
# magnitude_percentage_ratio_20_10      -0.094407  ...
# maximum_slope                         -0.062636  ...
# median_absolute_deviation             -0.059730  ...
# median_buffer_range_percentage_10     -0.014669  ...
# percent_amplitude                     -0.073151  ...
# mean_variance                         -0.075543  ...
# anderson_darling_normal               -0.001257  ...
# chi2                                  -0.012016  ...
# skew                                  -0.002947  ...
# stetson_K                             -0.055679  ...
#
#                                    magnitude_percentage_ratio_20_10  \
# mean                                                       0.019458
# weighted_mean                                             -0.026428
# standard_deviation                                         0.145493
# median                                                     0.034171
# amplitude                                                  0.063224
# beyond_1_std                                               0.560178
# cusum                                                      0.561254
# inter_percentile_range_10                                  0.092575
# kurtosis                                                   0.097879
# linear_trend                                              -0.094407
# linear_trend_sigma                                         0.055671
# linear_trend_noise                                         0.053274
# linear_fit_slope                                          -0.145345
# linear_fit_slope_sigma                                     0.017761
# linear_fit_reduced_chi2                                    0.012432
# magnitude_percentage_ratio_40_5                            0.705725
# magnitude_percentage_ratio_20_10                           1.000000
# maximum_slope                                              0.145526
# median_absolute_deviation                                  0.343139
# median_buffer_range_percentage_10                         -0.484570
# percent_amplitude                                          0.062849
# mean_variance                                              0.144422
# anderson_darling_normal                                   -0.452533
# chi2                                                       0.083742
# skew                                                      -0.084249
# stetson_K                                                  0.576029
#
#                                    maximum_slope  median_absolute_deviation  \
# mean                                   -0.004793                   0.374020
# weighted_mean                          -0.035192                   0.208282
# standard_deviation                      0.033102                   0.892925
# median                                 -0.006867                   0.390920
# amplitude                               0.108635                   0.775651
# beyond_1_std                            0.038465                   0.616519
# cusum                                   0.007037                   0.143853
# inter_percentile_range_10               0.017339                   0.870761
# kurtosis                                0.117384                  -0.270231
# linear_trend                           -0.062636                  -0.059730
# linear_trend_sigma                     -0.002122                   0.502315
# linear_trend_noise                      0.019880                   0.844527
# linear_fit_slope                       -0.080694                  -0.002647
# linear_fit_slope_sigma                  0.042840                   0.062054
# linear_fit_reduced_chi2                -0.026965                   0.569438
# magnitude_percentage_ratio_40_5         0.085306                   0.311394
# magnitude_percentage_ratio_20_10        0.145526                   0.343139
# maximum_slope                           1.000000                   0.065194
# median_absolute_deviation               0.065194                   1.000000
# median_buffer_range_percentage_10       0.033602                  -0.650558
# percent_amplitude                       0.121348                   0.656432
# mean_variance                           0.028445                   0.888335
# anderson_darling_normal                -0.096447                  -0.284331
# chi2                                   -0.017004                   0.608309
# skew                                    0.024968                  -0.367964
# stetson_K                               0.023745                   0.614393
#
#                                    median_buffer_range_percentage_10  \
# mean                                                       -0.348069
# weighted_mean                                              -0.278230
# standard_deviation                                         -0.551063
# median                                                     -0.356177
# amplitude                                                  -0.340979
# beyond_1_std                                               -0.717847
# cusum                                                      -0.253599
# inter_percentile_range_10                                  -0.534810
# kurtosis                                                    0.529230
# linear_trend                                               -0.014669
# linear_trend_sigma                                         -0.354434
# linear_trend_noise                                         -0.498147
# linear_fit_slope                                           -0.012340
# linear_fit_slope_sigma                                     -0.125978
# linear_fit_reduced_chi2                                    -0.290092
# magnitude_percentage_ratio_40_5                            -0.486044
# magnitude_percentage_ratio_20_10                           -0.484570
# maximum_slope                                               0.033602
# median_absolute_deviation                                  -0.650558
# median_buffer_range_percentage_10                           1.000000
# percent_amplitude                                          -0.228259
# mean_variance                                              -0.545654
# anderson_darling_normal                                     0.450810
# chi2                                                       -0.329848
# skew                                                        0.549969
# stetson_K                                                  -0.752270
#
#                                    percent_amplitude  mean_variance  \
# mean                                        0.351793       0.351480
# weighted_mean                               0.194106       0.177676
# standard_deviation                          0.834917       0.991707
# median                                      0.370482       0.371197
# amplitude                                   0.948371       0.901645
# beyond_1_std                                0.180067       0.449474
# cusum                                      -0.028671       0.044807
# inter_percentile_range_10                   0.816137       0.980921
# kurtosis                                   -0.033591      -0.315322
# linear_trend                               -0.073151      -0.075543
# linear_trend_sigma                          0.488133       0.567390
# linear_trend_noise                          0.846067       0.975035
# linear_fit_slope                            0.047294       0.047100
# linear_fit_slope_sigma                      0.055772       0.039967
# linear_fit_reduced_chi2                     0.608522       0.742692
# magnitude_percentage_ratio_40_5            -0.032701       0.063538
# magnitude_percentage_ratio_20_10            0.062849       0.144422
# maximum_slope                               0.121348       0.028445
# median_absolute_deviation                   0.656432       0.888335
# median_buffer_range_percentage_10          -0.228259      -0.545654
# percent_amplitude                           1.000000       0.825108
# mean_variance                               0.825108       1.000000
# anderson_darling_normal                    -0.147124      -0.155103
# chi2                                        0.585801       0.752436
# skew                                       -0.251736      -0.404056
# stetson_K                                   0.358604       0.546057
#
#                                    anderson_darling_normal      chi2  \
# mean                                             -0.124223 -0.074063
# weighted_mean                                    -0.096992 -0.181147
# standard_deviation                               -0.163842  0.686244
# median                                           -0.135046 -0.024390
# amplitude                                        -0.228381  0.626130
# beyond_1_std                                     -0.507979  0.272862
# cusum                                            -0.099380  0.002689
# inter_percentile_range_10                        -0.186253  0.679093
# kurtosis                                         -0.037964 -0.189328
# linear_trend                                     -0.001257 -0.012016
# linear_trend_sigma                               -0.204236  0.338129
# linear_trend_noise                               -0.170840  0.685792
# linear_fit_slope                                 -0.018502  0.073207
# linear_fit_slope_sigma                           -0.151497 -0.094244
# linear_fit_reduced_chi2                          -0.055015  0.975544
# magnitude_percentage_ratio_40_5                  -0.291995  0.009690
# magnitude_percentage_ratio_20_10                 -0.452533  0.083742
# maximum_slope                                    -0.096447 -0.017004
# median_absolute_deviation                        -0.284331  0.608309
# median_buffer_range_percentage_10                 0.450810 -0.329848
# percent_amplitude                                -0.147124  0.585801
# mean_variance                                    -0.155103  0.752436
# anderson_darling_normal                           1.000000 -0.052571
# chi2                                             -0.052571  1.000000
# skew                                              0.235173 -0.311316
# stetson_K                                        -0.385131  0.288585
#
#                                        skew  stetson_K
# mean                              -0.420871   0.423412
# weighted_mean                     -0.385688   0.314741
# standard_deviation                -0.417721   0.575349
# median                            -0.450475   0.455887
# amplitude                         -0.323894   0.428554
# beyond_1_std                      -0.469788   0.693924
# cusum                             -0.006888   0.420359
# inter_percentile_range_10         -0.428116   0.570381
# kurtosis                           0.620644  -0.377980
# linear_trend                      -0.002947  -0.055679
# linear_trend_sigma                -0.245589   0.329063
# linear_trend_noise                -0.424361   0.525819
# linear_fit_slope                  -0.081603   0.013772
# linear_fit_slope_sigma            -0.095531   0.068259
# linear_fit_reduced_chi2           -0.321197   0.237403
# magnitude_percentage_ratio_40_5   -0.017518   0.436923
# magnitude_percentage_ratio_20_10  -0.084249   0.576029
# maximum_slope                      0.024968   0.023745
# median_absolute_deviation         -0.367964   0.614393
# median_buffer_range_percentage_10  0.549969  -0.752270
# percent_amplitude                 -0.251736   0.358604
# mean_variance                     -0.404056   0.546057
# anderson_darling_normal            0.235173  -0.385131
# chi2                              -0.311316   0.288585
# skew                               1.000000  -0.410119
# stetson_K                         -0.410119   1.000000
#
# [26 rows x 26 columns]

# %%
#corr_diff =corr_combined_baseline_subset_all.abs()-corr_combined_baseline.abs()

# %%
corr_diff_1 = (corr_combined_baseline_subset_all - corr_combined_baseline)

# %%
corr_diff_1
# Out:
#                                        mean  weighted_mean  \
# mean                               0.000000      -0.006228
# weighted_mean                     -0.006228       0.000000
# standard_deviation                 0.111926       0.106426
# median                            -0.004315      -0.017897
# amplitude                          0.134740       0.130970
# beyond_1_std                       0.148720       0.094465
# cusum                             -0.049565      -0.068291
# inter_percentile_range_10          0.119462       0.114617
# kurtosis                          -0.106242      -0.097688
# linear_trend                      -0.101729      -0.050993
# linear_trend_sigma                 0.053362       0.058958
# linear_trend_noise                 0.123243       0.119783
# linear_fit_slope                   0.012834       0.039761
# linear_fit_slope_sigma             0.002404       0.029902
# linear_fit_reduced_chi2           -0.017339      -0.022467
# magnitude_percentage_ratio_40_5   -0.052297      -0.067899
# magnitude_percentage_ratio_20_10   0.000500      -0.034329
# maximum_slope                      0.021377       0.026774
# median_absolute_deviation          0.086914       0.077809
# median_buffer_range_percentage_10 -0.078172      -0.046404
# percent_amplitude                  0.130291       0.125831
# mean_variance                      0.098641       0.091725
# anderson_darling_normal           -0.104810      -0.050101
# chi2                              -0.018468      -0.026624
# skew                              -0.136651      -0.112530
# stetson_K                          0.168681       0.124848
#
#                                    standard_deviation    median  amplitude  \
# mean                                         0.111926 -0.004315   0.134740
# weighted_mean                                0.106426 -0.017897   0.130970
# standard_deviation                           0.000000  0.127001   0.011019
# median                                       0.127001  0.000000   0.149022
# amplitude                                    0.011019  0.149022   0.000000
# beyond_1_std                                 0.273027  0.159153   0.311318
# cusum                                        0.049027 -0.048370   0.041957
# inter_percentile_range_10                   -0.002204  0.133728   0.018322
# kurtosis                                    -0.153280 -0.102317  -0.167190
# linear_trend                                -0.113070 -0.127815  -0.103204
# linear_trend_sigma                           0.000676  0.057679   0.004363
# linear_trend_noise                          -0.002999  0.137557   0.016155
# linear_fit_slope                            -0.004049 -0.010604   0.008694
# linear_fit_slope_sigma                      -0.049581 -0.004641  -0.048421
# linear_fit_reduced_chi2                     -0.047632  0.003920  -0.016854
# magnitude_percentage_ratio_40_5              0.025056 -0.048265   0.037348
# magnitude_percentage_ratio_20_10             0.102352  0.012647   0.125674
# maximum_slope                               -0.098972  0.019415  -0.112635
# median_absolute_deviation                   -0.010061  0.101892   0.004857
# median_buffer_range_percentage_10           -0.193831 -0.087650  -0.268824
# percent_amplitude                            0.009086  0.145990  -0.011795
# mean_variance                               -0.001402  0.114245   0.008205
# anderson_darling_normal                     -0.322086 -0.113898  -0.358616
# chi2                                        -0.039137  0.003624  -0.016514
# skew                                        -0.254216 -0.139208  -0.270052
# stetson_K                                    0.198798  0.184698   0.247892
#
#                                    beyond_1_std     cusum  \
# mean                                   0.148720 -0.049565
# weighted_mean                          0.094465 -0.068291
# standard_deviation                     0.273027  0.049027
# median                                 0.159153 -0.048370
# amplitude                              0.311318  0.041957
# beyond_1_std                           0.000000 -0.091342
# cusum                                 -0.091342  0.000000
# inter_percentile_range_10              0.253054  0.030177
# kurtosis                              -0.040800  0.100198
# linear_trend                          -0.147807  0.025861
# linear_trend_sigma                     0.191332  0.043003
# linear_trend_noise                     0.269007  0.035835
# linear_fit_slope                      -0.103303 -0.002852
# linear_fit_slope_sigma                 0.060995  0.005792
# linear_fit_reduced_chi2                0.129433 -0.014650
# magnitude_percentage_ratio_40_5       -0.010435  0.004869
# magnitude_percentage_ratio_20_10      -0.014983  0.045845
# maximum_slope                          0.046851  0.084545
# median_absolute_deviation              0.224994  0.073213
# median_buffer_range_percentage_10     -0.128930  0.003252
# percent_amplitude                      0.278243  0.070118
# mean_variance                          0.265923  0.051192
# anderson_darling_normal               -0.223723 -0.084681
# chi2                                   0.137960  0.008040
# skew                                  -0.168776  0.096368
# stetson_K                              0.081040 -0.025216
#
#                                    inter_percentile_range_10  kurtosis  \
# mean                                                0.119462 -0.106242
# weighted_mean                                       0.114617 -0.097688
# standard_deviation                                 -0.002204 -0.153280
# median                                              0.133728 -0.102317
# amplitude                                           0.018322 -0.167190
# beyond_1_std                                        0.253054 -0.040800
# cusum                                               0.030177  0.100198
# inter_percentile_range_10                           0.000000 -0.148907
# kurtosis                                           -0.148907  0.000000
# linear_trend                                       -0.107473  0.008939
# linear_trend_sigma                                 -0.000083 -0.103714
# linear_trend_noise                                  0.000860 -0.156109
# linear_fit_slope                                    0.011815 -0.024325
# linear_fit_slope_sigma                             -0.047659 -0.026635
# linear_fit_reduced_chi2                            -0.046299 -0.090532
# magnitude_percentage_ratio_40_5                    -0.007559  0.089627
# magnitude_percentage_ratio_20_10                    0.073348  0.120122
# maximum_slope                                      -0.105094  0.030557
# median_absolute_deviation                          -0.028654 -0.109843
# median_buffer_range_percentage_10                  -0.171467  0.014562
# percent_amplitude                                   0.015820 -0.151610
# mean_variance                                      -0.005050 -0.152791
# anderson_darling_normal                            -0.307801 -0.085746
# chi2                                               -0.042921 -0.090673
# skew                                               -0.253740  0.107531
# stetson_K                                           0.182911  0.036341
#
#                                    linear_trend  ...  \
# mean                                  -0.101729  ...
# weighted_mean                         -0.050993  ...
# standard_deviation                    -0.113070  ...
# median                                -0.127815  ...
# amplitude                             -0.103204  ...
# beyond_1_std                          -0.147807  ...
# cusum                                  0.025861  ...
# inter_percentile_range_10             -0.107473  ...
# kurtosis                               0.008939  ...
# linear_trend                           0.000000  ...
# linear_trend_sigma                    -0.070988  ...
# linear_trend_noise                    -0.112892  ...
# linear_fit_slope                       0.004737  ...
# linear_fit_slope_sigma                -0.020732  ...
# linear_fit_reduced_chi2               -0.044638  ...
# magnitude_percentage_ratio_40_5        0.050198  ...
# magnitude_percentage_ratio_20_10      -0.086021  ...
# maximum_slope                         -0.040836  ...
# median_absolute_deviation             -0.121612  ...
# median_buffer_range_percentage_10      0.013704  ...
# percent_amplitude                     -0.079883  ...
# mean_variance                         -0.093459  ...
# anderson_darling_normal                0.051505  ...
# chi2                                  -0.034339  ...
# skew                                   0.077090  ...
# stetson_K                             -0.085251  ...
#
#                                    magnitude_percentage_ratio_20_10  \
# mean                                                       0.000500
# weighted_mean                                             -0.034329
# standard_deviation                                         0.102352
# median                                                     0.012647
# amplitude                                                  0.125674
# beyond_1_std                                              -0.014983
# cusum                                                      0.045845
# inter_percentile_range_10                                  0.073348
# kurtosis                                                   0.120122
# linear_trend                                              -0.086021
# linear_trend_sigma                                         0.088548
# linear_trend_noise                                         0.079852
# linear_fit_slope                                          -0.113262
# linear_fit_slope_sigma                                     0.045632
# linear_fit_reduced_chi2                                    0.021225
# magnitude_percentage_ratio_40_5                            0.008753
# magnitude_percentage_ratio_20_10                           0.000000
# maximum_slope                                              0.127666
# median_absolute_deviation                                  0.132308
# median_buffer_range_percentage_10                         -0.045075
# percent_amplitude                                          0.133298
# mean_variance                                              0.101274
# anderson_darling_normal                                   -0.302247
# chi2                                                       0.046144
# skew                                                       0.017373
# stetson_K                                                 -0.029911
#
#                                    maximum_slope  median_absolute_deviation  \
# mean                                    0.021377                   0.086914
# weighted_mean                           0.026774                   0.077809
# standard_deviation                     -0.098972                  -0.010061
# median                                  0.019415                   0.101892
# amplitude                              -0.112635                   0.004857
# beyond_1_std                            0.046851                   0.224994
# cusum                                   0.084545                   0.073213
# inter_percentile_range_10              -0.105094                  -0.028654
# kurtosis                                0.030557                  -0.109843
# linear_trend                           -0.040836                  -0.121612
# linear_trend_sigma                     -0.046706                   0.000850
# linear_trend_noise                     -0.103350                  -0.024897
# linear_fit_slope                       -0.059467                  -0.029432
# linear_fit_slope_sigma                  0.015281                  -0.035893
# linear_fit_reduced_chi2                -0.105102                  -0.072320
# magnitude_percentage_ratio_40_5         0.079336                   0.090680
# magnitude_percentage_ratio_20_10        0.127666                   0.132308
# maximum_slope                           0.000000                  -0.070994
# median_absolute_deviation              -0.070994                   0.000000
# median_buffer_range_percentage_10      -0.023331                  -0.180935
# percent_amplitude                      -0.096098                   0.004307
# mean_variance                          -0.104303                  -0.011712
# anderson_darling_normal                -0.071794                  -0.291662
# chi2                                   -0.094430                  -0.052468
# skew                                    0.026898                  -0.201293
# stetson_K                               0.054444                   0.174320
#
#                                    median_buffer_range_percentage_10  \
# mean                                                       -0.078172
# weighted_mean                                              -0.046404
# standard_deviation                                         -0.193831
# median                                                     -0.087650
# amplitude                                                  -0.268824
# beyond_1_std                                               -0.128930
# cusum                                                       0.003252
# inter_percentile_range_10                                  -0.171467
# kurtosis                                                    0.014562
# linear_trend                                                0.013704
# linear_trend_sigma                                         -0.135873
# linear_trend_noise                                         -0.176965
# linear_fit_slope                                           -0.023179
# linear_fit_slope_sigma                                     -0.031180
# linear_fit_reduced_chi2                                    -0.087898
# magnitude_percentage_ratio_40_5                            -0.002185
# magnitude_percentage_ratio_20_10                           -0.045075
# maximum_slope                                              -0.023331
# median_absolute_deviation                                  -0.180935
# median_buffer_range_percentage_10                           0.000000
# percent_amplitude                                          -0.254263
# mean_variance                                              -0.194965
# anderson_darling_normal                                     0.249802
# chi2                                                       -0.107900
# skew                                                        0.180211
# stetson_K                                                  -0.041577
#
#                                    percent_amplitude  mean_variance  \
# mean                                        0.130291       0.098641
# weighted_mean                               0.125831       0.091725
# standard_deviation                          0.009086      -0.001402
# median                                      0.145990       0.114245
# amplitude                                  -0.011795       0.008205
# beyond_1_std                                0.278243       0.265923
# cusum                                       0.070118       0.051192
# inter_percentile_range_10                   0.015820      -0.005050
# kurtosis                                   -0.151610      -0.152791
# linear_trend                               -0.079883      -0.093459
# linear_trend_sigma                          0.002948       0.003631
# linear_trend_noise                          0.014054      -0.005484
# linear_fit_slope                            0.014932       0.002117
# linear_fit_slope_sigma                     -0.045865      -0.051116
# linear_fit_reduced_chi2                    -0.003249      -0.037408
# magnitude_percentage_ratio_40_5             0.039808       0.028901
# magnitude_percentage_ratio_20_10            0.133298       0.101274
# maximum_slope                              -0.096098      -0.104303
# median_absolute_deviation                   0.004307      -0.011712
# median_buffer_range_percentage_10          -0.254263      -0.194965
# percent_amplitude                           0.000000       0.006007
# mean_variance                               0.006007       0.000000
# anderson_darling_normal                    -0.345772      -0.320283
# chi2                                       -0.004253      -0.028581
# skew                                       -0.259983      -0.250440
# stetson_K                                   0.241504       0.184241
#
#                                    anderson_darling_normal      chi2  \
# mean                                             -0.104810 -0.018468
# weighted_mean                                    -0.050101 -0.026624
# standard_deviation                               -0.322086 -0.039137
# median                                           -0.113898  0.003624
# amplitude                                        -0.358616 -0.016514
# beyond_1_std                                     -0.223723  0.137960
# cusum                                            -0.084681  0.008040
# inter_percentile_range_10                        -0.307801 -0.042921
# kurtosis                                         -0.085746 -0.090673
# linear_trend                                      0.051505 -0.034339
# linear_trend_sigma                               -0.163285 -0.005154
# linear_trend_noise                               -0.309547 -0.036601
# linear_fit_slope                                  0.002087  0.000198
# linear_fit_slope_sigma                           -0.025612 -0.051288
# linear_fit_reduced_chi2                          -0.219937 -0.001678
# magnitude_percentage_ratio_40_5                  -0.227003 -0.018915
# magnitude_percentage_ratio_20_10                 -0.302247  0.046144
# maximum_slope                                    -0.071794 -0.094430
# median_absolute_deviation                        -0.291662 -0.052468
# median_buffer_range_percentage_10                 0.249802 -0.107900
# percent_amplitude                                -0.345772 -0.004253
# mean_variance                                    -0.320283 -0.028581
# anderson_darling_normal                           0.000000 -0.223667
# chi2                                             -0.223667  0.000000
# skew                                              0.053283 -0.160076
# stetson_K                                        -0.277082  0.058926
#
#                                        skew  stetson_K
# mean                              -0.136651   0.168681
# weighted_mean                     -0.112530   0.124848
# standard_deviation                -0.254216   0.198798
# median                            -0.139208   0.184698
# amplitude                         -0.270052   0.247892
# beyond_1_std                      -0.168776   0.081040
# cusum                              0.096368  -0.025216
# inter_percentile_range_10         -0.253740   0.182911
# kurtosis                           0.107531   0.036341
# linear_trend                       0.077090  -0.085251
# linear_trend_sigma                -0.166023   0.132668
# linear_trend_noise                -0.262629   0.192245
# linear_fit_slope                   0.015720  -0.015886
# linear_fit_slope_sigma            -0.039713   0.048601
# linear_fit_reduced_chi2           -0.164627   0.044847
# magnitude_percentage_ratio_40_5    0.057850  -0.122212
# magnitude_percentage_ratio_20_10   0.017373  -0.029911
# maximum_slope                      0.026898   0.054444
# median_absolute_deviation         -0.201293   0.174320
# median_buffer_range_percentage_10  0.180211  -0.041577
# percent_amplitude                 -0.259983   0.241504
# mean_variance                     -0.250440   0.184241
# anderson_darling_normal            0.053283  -0.277082
# chi2                              -0.160076   0.058926
# skew                               0.000000  -0.166161
# stetson_K                         -0.166161   0.000000
#
# [26 rows x 26 columns]

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(corr_diff_1, cmap='bwr', center=0)
plt.title('Difference in Feature Correlations (baseline & subset_all elements)')
plt.tight_layout()
plt.show()

# %%
corr_diff_clean = corr_diff_1.copy()
corr_diff_clean[np.abs(corr_diff_clean) < 1e-6] = 0

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(corr_diff_clean, cmap='bwr', center=0, vmin=-1, vmax=1)
plt.title('Difference in Feature Correlations (baseline & subset_all elements)')
plt.tight_layout()
plt.show()

# %%
df_neg = pd.read_parquet(
    r"D:\Mcvs_clermont\current working directory\cluster_groups\subset of baseline with allneg & pos.parquet"
)

# %%
df_neg
# Out:
#             object       mean  weighted_mean  standard_deviation     median  \
# 0     ZTF18abachuh  13.602756      13.600786            0.194167  13.551601
# 1     ZTF18abebodz  15.655397      15.658733            0.238821  15.638908
# 2     ZTF18aaxyujl  15.917386      15.915512            0.098416  15.912807
# 3     ZTF18abfjmbl  16.087413      16.085389            0.086521  16.053020
# 4     ZTF18aayofec  18.284940      17.232688            1.134601  18.868792
# ...            ...        ...            ...                 ...        ...
# 1566      V418 Gem  16.905293      16.891739            0.130254  16.905872
# 1567      V677 And  19.227544      18.342081            0.989385  19.060970
# 1568     V2306 Cyg  15.869141      15.860906            0.180194  15.848884
# 1569        IL Leo  18.458933      17.494483            0.926653  18.622186
# 1570           Oph  15.821274      15.817911            0.129693  15.831488
#
#       amplitude  beyond_1_std     cusum  inter_percentile_range_10   kurtosis  \
# 0      1.594529      0.289233  0.235493                   0.475948  21.593521
# 1      0.669037      0.248913  0.253131                   0.456102   1.399115
# 2      0.389504      0.495868  0.381108                   0.246597  -1.035860
# 3      0.543823      0.349215  0.395872                   0.218258   1.683706
# 4      2.270712      0.361605  0.292773                   3.069963  -0.884689
# ...         ...           ...       ...                        ...        ...
# 1566   0.641553      0.319716  0.146000                   0.328610   0.831722
# 1567   2.745060      0.425414  0.429222                   2.542357  -1.123188
# 1568   1.344455      0.201835  0.180301                   0.363799  34.378112
# 1569   1.716861      0.440613  0.290478                   2.460330  -1.174519
# 1570   0.456778      0.285256  0.165112                   0.307883   1.460111
#
#       ...  median_absolute_deviation  median_buffer_range_percentage_10  \
# 0     ...                   0.088227                           0.675258
# 1     ...                   0.146764                           0.112500
# 2     ...                   0.095315                           0.196143
# 3     ...                   0.052219                           0.517596
# 4     ...                   0.657377                           0.363324
# ...   ...                        ...                                ...
# 1566  ...                   0.087836                           0.388099
# 1567  ...                   0.868201                           0.143646
# 1568  ...                   0.094182                           0.677982
# 1569  ...                   0.697933                           0.159004
# 1570  ...                   0.083125                           0.283120
#
#       percent_amplitude  mean_variance  anderson_darling_normal        chi2  \
# 0              2.727737       0.014274                49.220222  247.748572
# 1              0.844150       0.015255                53.605864  154.069571
# 2              0.434883       0.006183                51.271482   31.394575
# 3              0.744381       0.005378                64.653136   32.439946
# 4              3.056760       0.062051                70.756626  821.288483
# ...                 ...            ...                      ...         ...
# 1566           0.741325       0.007705                 0.198451   59.169751
# 1567           2.862148       0.051457                16.202306  199.179353
# 1568           2.232877       0.011355                19.465335   79.962911
# 1569           1.914783       0.050201                10.833990  352.659253
# 1570           0.603597       0.008197                 5.386825   57.958513
#
#           skew  stetson_K  cluster  cluster_id
# 0     2.059456   0.775113      1.0           1
# 1    -0.812027   0.820224      1.0           1
# 2     0.174029   0.885085      1.0           1
# 3     0.706887   0.869402      1.0           1
# 4    -0.586882   0.903019      9.0           9
# ...        ...        ...      ...         ...
# 1566 -0.083027   0.789198      NaN        None
# 1567  0.269137   0.853870      NaN        None
# 1568  3.661152   0.732837      NaN        None
# 1569 -0.240478   0.948347      NaN        None
# 1570 -0.836126   0.771527      NaN        None
#
# [1571 rows x 29 columns]

# %%
#df_combined_baseline_subset_all = pd.read_parquet("subset of baseline with allneg & pos.parquet")
features_neg = df_neg .drop(columns=['object','cluster','cluster_id'])#errors='ignore')
#features_combined_baseline_subset_all_numeric = features_combined_baseline_subset_all.select_dtypes(include='number')
corr_neg = features_neg.corr()

# %%
features_neg
# Out:
#            mean  weighted_mean  standard_deviation     median  amplitude  \
# 0     13.602756      13.600786            0.194167  13.551601   1.594529
# 1     15.655397      15.658733            0.238821  15.638908   0.669037
# 2     15.917386      15.915512            0.098416  15.912807   0.389504
# 3     16.087413      16.085389            0.086521  16.053020   0.543823
# 4     18.284940      17.232688            1.134601  18.868792   2.270712
# ...         ...            ...                 ...        ...        ...
# 1566  16.905293      16.891739            0.130254  16.905872   0.641553
# 1567  19.227544      18.342081            0.989385  19.060970   2.745060
# 1568  15.869141      15.860906            0.180194  15.848884   1.344455
# 1569  18.458933      17.494483            0.926653  18.622186   1.716861
# 1570  15.821274      15.817911            0.129693  15.831488   0.456778
#
#       beyond_1_std     cusum  inter_percentile_range_10   kurtosis  \
# 0         0.289233  0.235493                   0.475948  21.593521
# 1         0.248913  0.253131                   0.456102   1.399115
# 2         0.495868  0.381108                   0.246597  -1.035860
# 3         0.349215  0.395872                   0.218258   1.683706
# 4         0.361605  0.292773                   3.069963  -0.884689
# ...            ...       ...                        ...        ...
# 1566      0.319716  0.146000                   0.328610   0.831722
# 1567      0.425414  0.429222                   2.542357  -1.123188
# 1568      0.201835  0.180301                   0.363799  34.378112
# 1569      0.440613  0.290478                   2.460330  -1.174519
# 1570      0.285256  0.165112                   0.307883   1.460111
#
#       linear_trend  ...  magnitude_percentage_ratio_20_10  maximum_slope  \
# 0         0.000099  ...                          0.691962     219.923903
# 1        -0.000108  ...                          0.842541     219.414192
# 2        -0.000090  ...                          0.867072     584.065041
# 3         0.000077  ...                          0.791616     359.137470
# 4         0.000169  ...                          0.634668     551.500895
# ...            ...  ...                               ...            ...
# 1566      0.000015  ...                          0.673249     679.331641
# 1567      0.001677  ...                          0.796496     789.621964
# 1568     -0.000084  ...                          0.628867    2868.198512
# 1569     -0.000023  ...                          0.813309     848.642852
# 1570     -0.000033  ...                          0.674872     319.386942
#
#       median_absolute_deviation  median_buffer_range_percentage_10  \
# 0                      0.088227                           0.675258
# 1                      0.146764                           0.112500
# 2                      0.095315                           0.196143
# 3                      0.052219                           0.517596
# 4                      0.657377                           0.363324
# ...                         ...                                ...
# 1566                   0.087836                           0.388099
# 1567                   0.868201                           0.143646
# 1568                   0.094182                           0.677982
# 1569                   0.697933                           0.159004
# 1570                   0.083125                           0.283120
#
#       percent_amplitude  mean_variance  anderson_darling_normal        chi2  \
# 0              2.727737       0.014274                49.220222  247.748572
# 1              0.844150       0.015255                53.605864  154.069571
# 2              0.434883       0.006183                51.271482   31.394575
# 3              0.744381       0.005378                64.653136   32.439946
# 4              3.056760       0.062051                70.756626  821.288483
# ...                 ...            ...                      ...         ...
# 1566           0.741325       0.007705                 0.198451   59.169751
# 1567           2.862148       0.051457                16.202306  199.179353
# 1568           2.232877       0.011355                19.465335   79.962911
# 1569           1.914783       0.050201                10.833990  352.659253
# 1570           0.603597       0.008197                 5.386825   57.958513
#
#           skew  stetson_K
# 0     2.059456   0.775113
# 1    -0.812027   0.820224
# 2     0.174029   0.885085
# 3     0.706887   0.869402
# 4    -0.586882   0.903019
# ...        ...        ...
# 1566 -0.083027   0.789198
# 1567  0.269137   0.853870
# 1568  3.661152   0.732837
# 1569 -0.240478   0.948347
# 1570 -0.836126   0.771527
#
# [1571 rows x 26 columns]

# %%
corr_diff_2=(corr_neg - corr_combined_baseline)

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(corr_diff_2, cmap='bwr', center=0)
plt.title('Difference in Feature Correlations (baseline & subset_all elements)')
plt.tight_layout()
plt.show()

# %%
corr_diff_clean = corr_diff_2.copy()
corr_diff_clean[np.abs(corr_diff_clean) < 1e-6] = 0

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(corr_diff_clean, cmap='bwr', center=0, vmin=-1, vmax=1)
plt.title('Difference in Feature Correlations (baseline & subset_all elements)')
plt.tight_layout()
plt.show()
